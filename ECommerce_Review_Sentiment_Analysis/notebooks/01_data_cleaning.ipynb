# %%
import pandas as pd
import re

df = pd.read_csv("../data/reviews.csv")

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

df['clean_review'] = df['review'].apply(clean_text)

def get_sentiment(rating):
    if rating <= 2:
        return 'negative'
    elif rating == 3:
        return 'neutral'
    else:
        return 'positive'

df['sentiment'] = df['rating'].apply(get_sentiment)

df.to_csv("../data/reviews_clean.csv", index=False)
df.head()
# Out:
#                                review  rating  \
# 0     Great product, really loved it!       5
# 1      Terrible, broke after one use.       1
# 2              Okay, nothing special.       3
# 3  Excellent quality, will buy again.       5
# 4        Not good, very disappointed.       2
#
#                        clean_review sentiment
# 0     great product really loved it  positive
# 1      terrible broke after one use  negative
# 2              okay nothing special   neutral
# 3  excellent quality will buy again  positive
# 4        not good very disappointed  negative
